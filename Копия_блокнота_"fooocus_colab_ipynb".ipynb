# %% [markdown]
# <a href="https://colab.research.google.com/github/error0vlad-hub/tictactoe-deluxe/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22fooocus_colab_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fooocus Setup
# Репозиторий: [https://github.com/lllyasviel/Fooocus](https://github.com/lllyasviel/Fooocus)

# %%
import os

# 1. Установка совместимых версий для Colab Python 3.12
print("[1/4] Установка зависимостей...")
# Мы используем numpy<2 для совместимости с Fooocus и rembg
# !pip install pygit2==1.15.1 "numpy<2.0" "cupy-cuda12x==12.3.0" huggingface-hub==0.23.2 \
    transformers==4.42.4 pyyaml==6.0.1 rfc3987 safetensors==0.4.3 tqdm==4.66.4 \
    Jinja2==3.1.3 gradio==3.41.2 httpx==0.27.0 packaging==24.1 "pydantic<2.0" --force-reinstall -q

# 2. Подготовка репозитория
if not os.path.exists('/content/Fooocus'):
    print("[2/4] Клонирование репозитория...")
    # %cd /content
    # !git clone https://github.com/lllyasviel/Fooocus.git

# 3. Исправление ошибки импорта в pymatting (используется rembg)
# Это предотвратит падение, если cupy не загрузится корректно
# !sed -i 's/import cupy as cp/try:\n    import cupy as cp\nexcept ImportError:\n    cp = None/g' /usr/local/lib/python3.12/dist-packages/pymatting/foreground/estimate_foreground_ml_cupy.py 2>/dev/null || true

# 4. Запуск Fooocus
print("[4/4] Запуск Fooocus...")
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
