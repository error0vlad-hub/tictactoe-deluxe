# %% [markdown]
# # Fooocus Setup
# Репозиторий: [https://github.com/lllyasviel/Fooocus](https://github.com/lllyasviel/Fooocus)

# %%
import os

# 1. Принудительная установка зависимостей для устранения конфликтов
# Фиксируем Jinja2==3.0.3 и Gradio==3.41.2 для исправления ошибки 'unhashable type: dict'
print("[1/4] Установка зависимостей...")
# !pip install pygit2==1.15.1 numpy==1.26.4 huggingface-hub==0.23.2 transformers==4.42.4 \
    pyyaml==6.0.1 rfc3987 safetensors==0.4.3 tqdm==4.66.4 Jinja2==3.0.3 \
    gradio==3.41.2 httpx==0.27.0 packaging==24.1 "pydantic<2.0" --force-reinstall -q

# 2. Подготовка репозитория
if not os.path.exists('/content/Fooocus'):
    print("[2/4] Клонирование репозитория...")
    # %cd /content
    # !git clone https://github.com/lllyasviel/Fooocus.git

# 3. Проверка версии Jinja2 и авто-перезагрузка
import jinja2
if jinja2.__version__ != '3.0.3':
    print('\n[!] ПЕРЕЗАГРУЗКА СРЕДЫ... ПОЖАЛУЙСТА, ЗАПУСТИТЕ ЭТУ ЯЧЕЙКУ СНОВА ПОСЛЕ ЗАВЕРШЕНИЯ.')
    import os
    os._exit(0)

# 4. Запуск Fooocus
print("[4/4] Запуск Fooocus...")
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# !pip install pygit2==1.15.1
# !pip install numpy==1.26.4 cupy-cuda12x
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Version mismatch for gradio: Installed version 6.22.0 does not meet requirement gradio==3.41.2
# Installing requirements
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 75, in <module>
#     prepare_environment()
#   File "/content/Fooocus/launch.py", line 57, in prepare_environment
#     run_pip(f"install -r \"{requirements_file}\"", "requirements")
#   File "/content/Fooocus/modules/launch_util.py", line 70, in run_pip
#     return run(f'"{python}" -m pip {command} --prefer-binary{index_url_line}', desc=f"Installing {desc}",
# ...
